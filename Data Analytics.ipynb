# %%
#1.,15 Create ‘sales’ Data set having 5 columns namely: ID, TV, Radio, Newspaper and
#Sales.(random 5 entries) Build a linear regression model by identifying independent and
#target variable. Split the variables into training and testing sets. Then divide the training
#and testing sets into a 7:3 ratio, respectively and print them. Build a simple linear
#regression model.
# Import the numpy and pandas package
import numpy as np
import pandas as pd

# Read the given CSV file, and view some sample records
advertising = pd.read_csv("Company_data.csv")
advertising
# Shape of our dataset
advertising.shape

# Info our dataset
advertising.info()

# Describe our dataset
advertising.describe()

import matplotlib.pyplot as plt 
import seaborn as sns

# Using pairplot we'll visualize the data for correlation
sns.pairplot(advertising, x_vars=['TV', 'Radio','Newspaper'], 
             y_vars='Sales', size=4, aspect=1, kind='scatter')
plt.show()

sns.heatmap(advertising.corr(), cmap="YlGnBu", annot = True)
plt.show()

X = advertising['TV']
y = advertising['Sales']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7,test_size = 0.3, random_state = 100)

plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         200 non-null    int64
#  1   TV         200 non-null    float64
#  2   Radio      200 non-null    float64
#  3   Newspaper  200 non-null    float64
#  4   Sales      200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
'''13) x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
Use the given data and plot scatter. and find Polynomial linear Regression'''

import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
'''14,20) Create dataset Cars for following data- Visualizing the data and Splitting Data set in Dependent
and Independent variables. create linear regression model
Car          Model       Volume       Weight         CO2
Fiat          500          900         865            90
Toyota        Aygo        1000         790            99
Mitsubishi Space Star     1200        1160            95
Skoda        Citigo       1000         929            95'''
import numpy as np
import pandas as pd
df=pd.DataFrame(columns=['Car','Model','Volume','Weight','CO2'])
df.loc[0]=['Fiat',500,900,865,90]
df.loc[1]=['Toyota','Aygo',1000,790,99]
df.loc[2]=['Mitsubishi','Space Star',1200,1160,95]
df.loc[3]=['Skoda','Citigo',1000,929,95]
print(df)
print(df.shape)
print(df.info())
print(df.describe())

import matplotlib.pyplot as plt 
import seaborn as sns
sns.pairplot(df, x_vars=['Volume', 'Weight','CO2'], 
             y_vars='Car', size=4, aspect=1, kind='scatter')
plt.show()

sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()
# Out:
#           Car       Model Volume Weight CO2
# 0        Fiat         500    900    865  90
# 1      Toyota        Aygo   1000    790  99
# 2  Mitsubishi  Space Star   1200   1160  95
# 3       Skoda      Citigo   1000    929  95
# (4, 5)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Car     4 non-null      object
#  1   Model   4 non-null      object
#  2   Volume  4 non-null      object
#  3   Weight  4 non-null      object
#  4   CO2     4 non-null      object
# dtypes: object(5)
# memory usage: 192.0+ bytes
# None
#          Car  Model  Volume  Weight  CO2
# count      4      4       4       4    4
# unique     4      4       3       4    3
# top     Fiat    500    1000     865   95
# freq       1      1       2       1    2
# ...

# %%
'''16)22 ) Create the sample dataset

data = [['eggs', 'milk','bread'],
['eggs', 'apple'],
['milk', 'bread'],
['apple', 'milk'],
['milk', 'apple', 'bread']].
Generate association rules.'''

import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
transactions = [['eggs', 'milk','bread'],
['eggs', 'apple'],
['milk', 'bread'],
['apple', 'milk'],
['milk', 'apple', 'bread']]
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_array=te.fit(transactions).transform(transactions)
df=pd.DataFrame(te_array, columns=te.columns_)
df
freq_items = apriori(df, min_support = 0.5, use_colnames = True)
print(freq_items)
rules = association_rules(freq_items, metric ='support', min_threshold=0.05)
rules = rules.sort_values(['support', 'confidence'], ascending =[False,False])
print(rules)
# Out:
#    support       itemsets
# 0      0.6        (apple)
# 1      0.6        (bread)
# 2      0.8         (milk)
# 3      0.6  (bread, milk)
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (bread)      (milk)                 0.6                 0.8      0.6
# 1      (milk)     (bread)                 0.8                 0.6      0.6
#
#    confidence  lift  leverage  conviction
# 0        1.00  1.25      0.12         inf
# 1        0.75  1.25      0.12         1.6

# %%
'''17) x = [2,5,8,4,12,5,6]
y = [4,7,9,8,6,5,10]
Use the given data and plot scatter. and find Polynomial linear Regression'''

import numpy
import matplotlib.pyplot as plt

x = [2,5,8,4,12,5,6]
y = [4,7,9,8,6,5,10]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
'''18) Create the following dataset in python
No. Items
1 Bread, Milk
2 Bread diaper, Egg, Beer
3 Milk, diaper, Beer,Coke
4 Bread , Milk, diaper, Beer
5 Bread , Milk, diaper, coke
Convert the categorical values into numeric format. Generate the association rules'''

import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
transactions = [['Bread', 'milk'],
['Bread', 'Diaper','Beer','Eggs'],
['Milk', 'Diaper','Beer','Coke'],
['apple', 'milk'],
['milk', 'apple', 'bread']]
transactions
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_array=te.fit(transactions).transform(transactions)
df=pd.DataFrame(te_array, columns=te.columns_)
df
freq_items = apriori(df, min_support = 0.5, use_colnames = True)
print(freq_items)
rules = association_rules(freq_items, metric ='support', min_threshold=0.05)
rules = rules.sort_values(['support', 'confidence'], ascending =[False,False])
# Out:
#    support itemsets
# 0      0.6   (milk)

# %%
'''19) Create dataframe with 5 subjects and marks of 10 students for each subject. plot a scatter plot
graph between ‘subject’ and ‘marks’.'''

import pandas as pd
subject=['electronics','maths','stats','english','DA']
marks=[]

# %%
'''23)X=[5,7,8,7,2,17,2,9,4,11,12,9,6]
Y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
Use the given data and plot scatter. and find simple linear Regression.'''

import matplotlib.pyplot as plt
X=[5,7,8,7,2,17,2,9,4,11,12,9,6]
Y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(X,Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
'''24)Create own Youtube dataset having characteristics (video-id, title, publish-time, views, likes ). Add
10 records and visualizing the data by plotting a scatter plot graph between ‘views’ and ‘Likes’.'''

import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame(columns=['video-id','title','publish-time','views','likes'])
df.loc[0]=[32337,'nepal vlog',8,45,23]
df.loc[1]=[32337,'bhutan vlog',9,70,99]
df.loc[2]=[32337,'nepal vlog',8,10,6]
df.loc[3]=[32337,'shimla vlog',7,929,95]
df.loc[4]=[32337,'nepal vlogo',9,92,9]
df.loc[5]=[32337,'lonavla vlog',2,929,95]
print(df)

import matplotlib.pyplot as plt
plt.scatter('views','likes')
# Out:
#    video-id         title  publish-time  views  likes
# 0     32337    nepal vlog             8     45     23
# 1     32337   bhutan vlog             9     70     99
# 2     32337    nepal vlog             8     10      6
# 3     32337   shimla vlog             7    929     95
# 4     32337   nepal vlogo             9     92      9
# 5     32337  lonavla vlog             2    929     95
